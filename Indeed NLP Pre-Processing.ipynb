# %% [markdown]
# # Pre-Processing Indeed Employee Comments

# %% [markdown]
# ### Importing The Necessary Libraries

# %%
import pandas as pd
import numpy as np
import nltk
import string
import fasttext
import pickle
import contractions
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords, wordnet
from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS
from nltk.stem import WordNetLemmatizer

pd.options.mode.chained_assignment = None
pd.set_option('display.max_colwidth', 100)

# %%
with open('indeed_scrape.csv') as f:
    df = pd.read_csv(f)
f.close()

# %%
df.head()
# Out:
#    Unnamed: 0  rating                             rating_title  \
# 0           0       4  Design work with their engineering team
# 1           1       5                   Great work environment
# 2           2       5                       Nice place to work
# 3           3       5         \uma empesa ótima para trabalhar
# 4           4       5                     Amazing work culture
#
#                                                                                     rating_description  \
# 0  Contracted to design custom pitot test adapters. Involved multiple design phases and prototypes....
# 1  Lots of support and collaboration across many engaging projects. You are given an opportunity to...
# 2  Work is responsibility. Culture is great. The Hardest part of job is that it is very hectic. Man...
# 3  A melhor empresa que trabalhei. A viagem que ganhei aos EUA - Moutain View para conhecer a sede ...
# 4  An amazing work environment where everyone is very smart and friendly. I have learned a lot from...
#
#   rating_pros rating_cons
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
# it was not uncommon to see rating_pros and rating_cons to be missing
# not worried about a missing rating_title as we wouldn't be using this data for analysis 
for col in df.columns:
    print(col, df[col].isnull().sum())
# Out:
# rating 0
# rating_title 7
# rating_description 0
# rating_pros 2278
# rating_cons 2440

# %%
# we'll be using rating and rating_description exclusively for our work. 
rws = df.loc[:, ['rating', 'rating_description']]
rws.head()
# Out:
#    rating  \
# 0       4
# 1       5
# 2       5
# 3       5
# 4       5
#
#                                                                                     rating_description
# 0  Contracted to design custom pitot test adapters. Involved multiple design phases and prototypes....
# 1  Lots of support and collaboration across many engaging projects. You are given an opportunity to...
# 2  Work is responsibility. Culture is great. The Hardest part of job is that it is very hectic. Man...
# 3  A melhor empresa que trabalhei. A viagem que ganhei aos EUA - Moutain View para conhecer a sede ...
# 4  An amazing work environment where everyone is very smart and friendly. I have learned a lot from...

# %% [markdown]
# ## Data Pre-Processing

# %% [markdown]
# Let's begin by expanding any contractions we might have (ie. "I've" or "I'll").  Keep in mind that this will effectively tokenize the rating descriptions but each contraction wil be a single token.  I other words, "I've" will be "I have" instead of "I", "Have".

# %%
rws['no_contract'] = rws['rating_description'].apply(lambda x: [contractions.fix(word) for word in x.split()])
rws.head(25)
# Out:
#     rating  \
# 0        4
# 1        5
# 2        5
# 3        5
# 4        5
# 5        5
# 6        5
# 7        5
# 8        5
# 9        4
# 10       4
# 11       5
# 12       3
# 13       5
# 14       5
# 15       5
# 16       4
# 17       5
# 18       5
# 19       4
# 20       4
# 21       4
# 22       5
# 23       4
# 24       5
#
#                                                                                      rating_description  \
# 0   Contracted to design custom pitot test adapters. Involved multiple design phases and prototypes....
# 1   Lots of support and collaboration across many engaging projects. You are given an opportunity to...
# 2   Work is responsibility. Culture is great. The Hardest part of job is that it is very hectic. Man...
# 3   A melhor empresa que trabalhei. A viagem que ganhei aos EUA - Moutain View para conhecer a sede ...
# 4   An amazing work environment where everyone is very smart and friendly. I have learned a lot from...
# 5   A productive and innovative culture and environment. Fostered creativity and did not limit your ...
# 6   Technically strong people. Google was client and i wasn't directly working for google..  We had ...
# 7   I was on contract at Google for 7 months and loved every minute of it! The people are great and ...
# 8   Great experience. Great perspective. Google fiber optics. Great place to get your cash and check...
# 9   I really enjoyed working there. It was a great environment, had good food free lunch and made go...
# 10  To be an accomplished Design Engineer specializing in object oriented design and analysis and to...
# 11  Best platform for getting good knowledge  and well formed culture. Work with good timings,well o...
# 12  Prefiro não ter mais nenhuma experiência com a empresa aqui no Brasil. Talvez em outro país seja...
# 13                                     A good place to learn and apply your expertise. good experience.
# 14  Fun engaging corporate culture. Very mart people. Lots to learn across verticals and technologie...
# 15  like it , good food , fun place . leaving because my manager was terrible. recommendation: ask a...
# 16                              ambiente di lavoro stimolante; Management Stabilità del lavoro/Carriera
# 17  It's not a startup anymore, but still an amazing place to work! You learn so much from working w...
# 18  I learned a lot in this company about technology and navigation . This was a big opportunity for...
# 19  Google is a great place to work.  Respectful coworkers and management.  The promotions can be ve...
# 20  Google is a good work environment. There are a lot of perks and opportunities available to advan...
# 21  Contracted to design custom pitot test adapters. Involved multiple design phases and prototypes....
# 22  The goal of the consultancy project was to improve YouTube quality perception in the digital mar...
# 23                                                   Es un lugar de aprendizaje constante y desarrollo.
# 24  Great company to work for I hate that my assignment ended I would love to go back to Google this...
#
#                                                                                             no_contract
# 0   [Contracted, to, design, custom, pitot, test, adapters., Involved, multiple, design, phases, and...
# 1   [Lots, of, support, and, collaboration, across, many, engaging, projects., You, are, given, an, ...
# 2   [Work, is, responsibility., Culture, is, great., The, Hardest, part, of, job, is, that, it, is, ...
# 3   [A, melhor, empresa, que, trabalhei., A, viagem, que, ganhei, aos, EUA, -, Moutain, View, para, ...
# 4   [An, amazing, work, environment, where, everyone, is, very, smart, and, friendly., I, have, lear...
# 5   [A, productive, and, innovative, culture, and, environment., Fostered, creativity, and, did, not...
# 6   [Technically, strong, people., Google, was, client, and, i, was not, directly, working, for, goo...
# 7   [I, was, on, contract, at, Google, for, 7, months, and, loved, every, minute, of, it!, The, peop...
# 8   [Great, experience., Great, perspective., Google, fiber, optics., Great, place, to, get, your, c...
# 9   [I, really, enjoyed, working, there., It, was, a, great, environment,, had, good, food, free, lu...
# 10  [To, be, an, accomplished, Design, Engineer, specializing, in, object, oriented, design, and, an...
# 11  [Best, platform, for, getting, good, knowledge, and, well, formed, culture., Work, with, good, t...
# 12  [Prefiro, não, ter, mais, nenhuma, experiência, com, a, empresa, aqui, no, Brasil., Talvez, em, ...
# 13                         [A, good, place, to, learn, and, apply, your, expertise., good, experience.]
# 14  [Fun, engaging, corporate, culture., Very, mart, people., Lots, to, learn, across, verticals, an...
# 15  [like, it, ,, good, food, ,, fun, place, ., leaving, because, my, manager, was, terrible., recom...
# 16                     [ambiente, di, lavoro, stimolante;, Management, Stabilità, del, lavoro/Carriera]
# 17  [it is, not, a, startup, anymore,, but, still, an, amazing, place, to, work!, You, learn, so, mu...
# 18  [I, learned, a, lot, in, this, company, about, technology, and, navigation, ., This, was, a, big...
# 19  [Google, is, a, great, place, to, work., Respectful, coworkers, and, management., The, promotion...
# 20  [Google, is, a, good, work, environment., There, are, a, lot, of, perks, and, opportunities, ava...
# 21  [Contracted, to, design, custom, pitot, test, adapters., Involved, multiple, design, phases, and...
# 22  [The, goal, of, the, consultancy, project, was, to, improve, YouTube, quality, perception, in, t...
# 23                                          [Es, un, lugar, de, aprendizaje, constante, y, desarrollo.]
# 24  [Great, company, to, work, for, I, hate, that, my, assignment, ended, I, would, love, to, go, ba...

# %% [markdown]
# Now that the contractions are expanded let's turn the list back into a string so we can properly tokenize the expanded contractions as two separate tokens instead of one.

# %%
rws['rating_description_str'] = [' '.join(map(str, l)) for l in rws['no_contract']]
rws.head()
# Out:
#    rating  \
# 0       4
# 1       5
# 2       5
# 3       5
# 4       5
#
#                                                                                     rating_description  \
# 0  Contracted to design custom pitot test adapters. Involved multiple design phases and prototypes....
# 1  Lots of support and collaboration across many engaging projects. You are given an opportunity to...
# 2  Work is responsibility. Culture is great. The Hardest part of job is that it is very hectic. Man...
# 3  A melhor empresa que trabalhei. A viagem que ganhei aos EUA - Moutain View para conhecer a sede ...
# 4  An amazing work environment where everyone is very smart and friendly. I have learned a lot from...
#
#                                                                                            no_contract  \
# 0  [Contracted, to, design, custom, pitot, test, adapters., Involved, multiple, design, phases, and...
# 1  [Lots, of, support, and, collaboration, across, many, engaging, projects., You, are, given, an, ...
# 2  [Work, is, responsibility., Culture, is, great., The, Hardest, part, of, job, is, that, it, is, ...
# 3  [A, melhor, empresa, que, trabalhei., A, viagem, que, ganhei, aos, EUA, -, Moutain, View, para, ...
# 4  [An, amazing, work, environment, where, everyone, is, very, smart, and, friendly., I, have, lear...
#
#                                                                                 rating_description_str
# 0  Contracted to design custom pitot test adapters. Involved multiple design phases and prototypes....
# 1  Lots of support and collaboration across many engaging projects. You are given an opportunity to...
# 2  Work is responsibility. Culture is great. The Hardest part of job is that it is very hectic. Man...
# 3  A melhor empresa que trabalhei. A viagem que ganhei aos EUA - Moutain View para conhecer a sede ...
# 4  An amazing work environment where everyone is very smart and friendly. I have learned a lot from...

# %%
# Language detection
# download the pretrained model 
#  https://dl.fbaipublicfiles.com/fasttext/supervised-models/lid.176.bin
pretrained_model = "lid.176.bin" 
model = fasttext.load_model(pretrained_model)

langs = []
for sent in rws['rating_description_str']:
    lang = model.predict(sent)[0]
    langs.append(str(lang)[11:13])

rws['langs'] = langs

rws.head()
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
#    rating  \
# 0       4
# 1       5
# 2       5
# 3       5
# 4       5
#
#                                                                                     rating_description  \
# 0  Contracted to design custom pitot test adapters. Involved multiple design phases and prototypes....
# 1  Lots of support and collaboration across many engaging projects. You are given an opportunity to...
# 2  Work is responsibility. Culture is great. The Hardest part of job is that it is very hectic. Man...
# 3  A melhor empresa que trabalhei. A viagem que ganhei aos EUA - Moutain View para conhecer a sede ...
# 4  An amazing work environment where everyone is very smart and friendly. I have learned a lot from...
#
#                                                                                            no_contract  \
# 0  [Contracted, to, design, custom, pitot, test, adapters., Involved, multiple, design, phases, and...
# 1  [Lots, of, support, and, collaboration, across, many, engaging, projects., You, are, given, an, ...
# 2  [Work, is, responsibility., Culture, is, great., The, Hardest, part, of, job, is, that, it, is, ...
# 3  [A, melhor, empresa, que, trabalhei., A, viagem, que, ganhei, aos, EUA, -, Moutain, View, para, ...
# 4  [An, amazing, work, environment, where, everyone, is, very, smart, and, friendly., I, have, lear...
#
#                                                                                 rating_description_str  \
# 0  Contracted to design custom pitot test adapters. Involved multiple design phases and prototypes....
# 1  Lots of support and collaboration across many engaging projects. You are given an opportunity to...
# 2  Work is responsibility. Culture is great. The Hardest part of job is that it is very hectic. Man...
# 3  A melhor empresa que trabalhei. A viagem que ganhei aos EUA - Moutain View para conhecer a sede ...
# 4  An amazing work environment where everyone is very smart and friendly. I have learned a lot from...
#
#   langs
# 0    en
# 1    en
# 2    en
# 3    pt
# 4    en

# %%
# removing non-english reviews
rws = rws[rws['langs'] == 'en']
rws.head()
# Out:
#    rating  \
# 0       4
# 1       5
# 2       5
# 4       5
# 5       5
#
#                                                                                     rating_description  \
# 0  Contracted to design custom pitot test adapters. Involved multiple design phases and prototypes....
# 1  Lots of support and collaboration across many engaging projects. You are given an opportunity to...
# 2  Work is responsibility. Culture is great. The Hardest part of job is that it is very hectic. Man...
# 4  An amazing work environment where everyone is very smart and friendly. I have learned a lot from...
# 5  A productive and innovative culture and environment. Fostered creativity and did not limit your ...
#
#                                                                                            no_contract  \
# 0  [Contracted, to, design, custom, pitot, test, adapters., Involved, multiple, design, phases, and...
# 1  [Lots, of, support, and, collaboration, across, many, engaging, projects., You, are, given, an, ...
# 2  [Work, is, responsibility., Culture, is, great., The, Hardest, part, of, job, is, that, it, is, ...
# 4  [An, amazing, work, environment, where, everyone, is, very, smart, and, friendly., I, have, lear...
# 5  [A, productive, and, innovative, culture, and, environment., Fostered, creativity, and, did, not...
#
#                                                                                 rating_description_str  \
# 0  Contracted to design custom pitot test adapters. Involved multiple design phases and prototypes....
# 1  Lots of support and collaboration across many engaging projects. You are given an opportunity to...
# 2  Work is responsibility. Culture is great. The Hardest part of job is that it is very hectic. Man...
# 4  An amazing work environment where everyone is very smart and friendly. I have learned a lot from...
# 5  A productive and innovative culture and environment. Fostered creativity and did not limit your ...
#
#   langs
# 0    en
# 1    en
# 2    en
# 4    en
# 5    en

# %% [markdown]
# Now let's tokenize as normal and the expanded contracts will be tokenized accurately.

# %%
rws['tokenized'] = rws['rating_description_str'].apply(word_tokenize)
rws.head()
# Out:
#    rating  \
# 0       4
# 1       5
# 2       5
# 4       5
# 5       5
#
#                                                                                     rating_description  \
# 0  Contracted to design custom pitot test adapters. Involved multiple design phases and prototypes....
# 1  Lots of support and collaboration across many engaging projects. You are given an opportunity to...
# 2  Work is responsibility. Culture is great. The Hardest part of job is that it is very hectic. Man...
# 4  An amazing work environment where everyone is very smart and friendly. I have learned a lot from...
# 5  A productive and innovative culture and environment. Fostered creativity and did not limit your ...
#
#                                                                                            no_contract  \
# 0  [Contracted, to, design, custom, pitot, test, adapters., Involved, multiple, design, phases, and...
# 1  [Lots, of, support, and, collaboration, across, many, engaging, projects., You, are, given, an, ...
# 2  [Work, is, responsibility., Culture, is, great., The, Hardest, part, of, job, is, that, it, is, ...
# 4  [An, amazing, work, environment, where, everyone, is, very, smart, and, friendly., I, have, lear...
# 5  [A, productive, and, innovative, culture, and, environment., Fostered, creativity, and, did, not...
#
#                                                                                 rating_description_str  \
# 0  Contracted to design custom pitot test adapters. Involved multiple design phases and prototypes....
# 1  Lots of support and collaboration across many engaging projects. You are given an opportunity to...
# 2  Work is responsibility. Culture is great. The Hardest part of job is that it is very hectic. Man...
# 4  An amazing work environment where everyone is very smart and friendly. I have learned a lot from...
# 5  A productive and innovative culture and environment. Fostered creativity and did not limit your ...
#
#   langs  \
# 0    en
# 1    en
# 2    en
# 4    en
# 5    en
#
#                                                                                              tokenized
# 0  [Contracted, to, design, custom, pitot, test, adapters, ., Involved, multiple, design, phases, a...
# 1  [Lots, of, support, and, collaboration, across, many, engaging, projects, ., You, are, given, an...
# 2  [Work, is, responsibility, ., Culture, is, great, ., The, Hardest, part, of, job, is, that, it, ...
# 4  [An, amazing, work, environment, where, everyone, is, very, smart, and, friendly, ., I, have, le...
# 5  [A, productive, and, innovative, culture, and, environment, ., Fostered, creativity, and, did, n...

# %%
rws['lower'] = rws['tokenized'].apply(lambda x: [word.lower() for word in x])
rws.head()
# Out:
#    rating  \
# 0       4
# 1       5
# 2       5
# 4       5
# 5       5
#
#                                                                                     rating_description  \
# 0  Contracted to design custom pitot test adapters. Involved multiple design phases and prototypes....
# 1  Lots of support and collaboration across many engaging projects. You are given an opportunity to...
# 2  Work is responsibility. Culture is great. The Hardest part of job is that it is very hectic. Man...
# 4  An amazing work environment where everyone is very smart and friendly. I have learned a lot from...
# 5  A productive and innovative culture and environment. Fostered creativity and did not limit your ...
#
#                                                                                            no_contract  \
# 0  [Contracted, to, design, custom, pitot, test, adapters., Involved, multiple, design, phases, and...
# 1  [Lots, of, support, and, collaboration, across, many, engaging, projects., You, are, given, an, ...
# 2  [Work, is, responsibility., Culture, is, great., The, Hardest, part, of, job, is, that, it, is, ...
# 4  [An, amazing, work, environment, where, everyone, is, very, smart, and, friendly., I, have, lear...
# 5  [A, productive, and, innovative, culture, and, environment., Fostered, creativity, and, did, not...
#
#                                                                                 rating_description_str  \
# 0  Contracted to design custom pitot test adapters. Involved multiple design phases and prototypes....
# 1  Lots of support and collaboration across many engaging projects. You are given an opportunity to...
# 2  Work is responsibility. Culture is great. The Hardest part of job is that it is very hectic. Man...
# 4  An amazing work environment where everyone is very smart and friendly. I have learned a lot from...
# 5  A productive and innovative culture and environment. Fostered creativity and did not limit your ...
#
#   langs  \
# 0    en
# 1    en
# 2    en
# 4    en
# 5    en
#
#                                                                                              tokenized  \
# 0  [Contracted, to, design, custom, pitot, test, adapters, ., Involved, multiple, design, phases, a...
# 1  [Lots, of, support, and, collaboration, across, many, engaging, projects, ., You, are, given, an...
# 2  [Work, is, responsibility, ., Culture, is, great, ., The, Hardest, part, of, job, is, that, it, ...
# 4  [An, amazing, work, environment, where, everyone, is, very, smart, and, friendly, ., I, have, le...
# 5  [A, productive, and, innovative, culture, and, environment, ., Fostered, creativity, and, did, n...
#
#                                                                                                  lower
# 0  [contracted, to, design, custom, pitot, test, adapters, ., involved, multiple, design, phases, a...
# 1  [lots, of, support, and, collaboration, across, many, engaging, projects, ., you, are, given, an...
# 2  [work, is, responsibility, ., culture, is, great, ., the, hardest, part, of, job, is, that, it, ...
# 4  [an, amazing, work, environment, where, everyone, is, very, smart, and, friendly, ., i, have, le...
# 5  [a, productive, and, innovative, culture, and, environment, ., fostered, creativity, and, did, n...

# %%
punc = string.punctuation
rws['no_punc'] = rws['lower'].apply(lambda x: [word for word in x if word not in punc])
rws.head()
# Out:
#    rating  \
# 0       4
# 1       5
# 2       5
# 4       5
# 5       5
#
#                                                                                     rating_description  \
# 0  Contracted to design custom pitot test adapters. Involved multiple design phases and prototypes....
# 1  Lots of support and collaboration across many engaging projects. You are given an opportunity to...
# 2  Work is responsibility. Culture is great. The Hardest part of job is that it is very hectic. Man...
# 4  An amazing work environment where everyone is very smart and friendly. I have learned a lot from...
# 5  A productive and innovative culture and environment. Fostered creativity and did not limit your ...
#
#                                                                                            no_contract  \
# 0  [Contracted, to, design, custom, pitot, test, adapters., Involved, multiple, design, phases, and...
# 1  [Lots, of, support, and, collaboration, across, many, engaging, projects., You, are, given, an, ...
# 2  [Work, is, responsibility., Culture, is, great., The, Hardest, part, of, job, is, that, it, is, ...
# 4  [An, amazing, work, environment, where, everyone, is, very, smart, and, friendly., I, have, lear...
# 5  [A, productive, and, innovative, culture, and, environment., Fostered, creativity, and, did, not...
#
#                                                                                 rating_description_str  \
# 0  Contracted to design custom pitot test adapters. Involved multiple design phases and prototypes....
# 1  Lots of support and collaboration across many engaging projects. You are given an opportunity to...
# 2  Work is responsibility. Culture is great. The Hardest part of job is that it is very hectic. Man...
# 4  An amazing work environment where everyone is very smart and friendly. I have learned a lot from...
# 5  A productive and innovative culture and environment. Fostered creativity and did not limit your ...
#
#   langs  \
# 0    en
# 1    en
# 2    en
# 4    en
# 5    en
#
#                                                                                              tokenized  \
# 0  [Contracted, to, design, custom, pitot, test, adapters, ., Involved, multiple, design, phases, a...
# 1  [Lots, of, support, and, collaboration, across, many, engaging, projects, ., You, are, given, an...
# 2  [Work, is, responsibility, ., Culture, is, great, ., The, Hardest, part, of, job, is, that, it, ...
# 4  [An, amazing, work, environment, where, everyone, is, very, smart, and, friendly, ., I, have, le...
# 5  [A, productive, and, innovative, culture, and, environment, ., Fostered, creativity, and, did, n...
#
#                                                                                                  lower  \
# 0  [contracted, to, design, custom, pitot, test, adapters, ., involved, multiple, design, phases, a...
# 1  [lots, of, support, and, collaboration, across, many, engaging, projects, ., you, are, given, an...
# 2  [work, is, responsibility, ., culture, is, great, ., the, hardest, part, of, job, is, that, it, ...
# 4  [an, amazing, work, environment, where, everyone, is, very, smart, and, friendly, ., i, have, le...
# 5  [a, productive, and, innovative, culture, and, environment, ., fostered, creativity, and, did, n...
#
#                                                                                                no_punc
# 0  [contracted, to, design, custom, pitot, test, adapters, involved, multiple, design, phases, and,...
# 1  [lots, of, support, and, collaboration, across, many, engaging, projects, you, are, given, an, o...
# 2  [work, is, responsibility, culture, is, great, the, hardest, part, of, job, is, that, it, is, ve...
# 4  [an, amazing, work, environment, where, everyone, is, very, smart, and, friendly, i, have, learn...
# 5  [a, productive, and, innovative, culture, and, environment, fostered, creativity, and, did, not,...

# %%
stop_words = set(stopwords.words('english'))
rws['stopwords_removed'] = rws['no_punc'].apply(lambda x: [word for word in x if word not in stop_words])
rws.head()
# Out:
#    rating  \
# 0       4
# 1       5
# 2       5
# 4       5
# 5       5
#
#                                                                                     rating_description  \
# 0  Contracted to design custom pitot test adapters. Involved multiple design phases and prototypes....
# 1  Lots of support and collaboration across many engaging projects. You are given an opportunity to...
# 2  Work is responsibility. Culture is great. The Hardest part of job is that it is very hectic. Man...
# 4  An amazing work environment where everyone is very smart and friendly. I have learned a lot from...
# 5  A productive and innovative culture and environment. Fostered creativity and did not limit your ...
#
#                                                                                            no_contract  \
# 0  [Contracted, to, design, custom, pitot, test, adapters., Involved, multiple, design, phases, and...
# 1  [Lots, of, support, and, collaboration, across, many, engaging, projects., You, are, given, an, ...
# 2  [Work, is, responsibility., Culture, is, great., The, Hardest, part, of, job, is, that, it, is, ...
# 4  [An, amazing, work, environment, where, everyone, is, very, smart, and, friendly., I, have, lear...
# 5  [A, productive, and, innovative, culture, and, environment., Fostered, creativity, and, did, not...
#
#                                                                                 rating_description_str  \
# 0  Contracted to design custom pitot test adapters. Involved multiple design phases and prototypes....
# 1  Lots of support and collaboration across many engaging projects. You are given an opportunity to...
# 2  Work is responsibility. Culture is great. The Hardest part of job is that it is very hectic. Man...
# 4  An amazing work environment where everyone is very smart and friendly. I have learned a lot from...
# 5  A productive and innovative culture and environment. Fostered creativity and did not limit your ...
#
#   langs  \
# 0    en
# 1    en
# 2    en
# 4    en
# 5    en
#
#                                                                                              tokenized  \
# 0  [Contracted, to, design, custom, pitot, test, adapters, ., Involved, multiple, design, phases, a...
# 1  [Lots, of, support, and, collaboration, across, many, engaging, projects, ., You, are, given, an...
# 2  [Work, is, responsibility, ., Culture, is, great, ., The, Hardest, part, of, job, is, that, it, ...
# 4  [An, amazing, work, environment, where, everyone, is, very, smart, and, friendly, ., I, have, le...
# 5  [A, productive, and, innovative, culture, and, environment, ., Fostered, creativity, and, did, n...
#
#                                                                                                  lower  \
# 0  [contracted, to, design, custom, pitot, test, adapters, ., involved, multiple, design, phases, a...
# 1  [lots, of, support, and, collaboration, across, many, engaging, projects, ., you, are, given, an...
# 2  [work, is, responsibility, ., culture, is, great, ., the, hardest, part, of, job, is, that, it, ...
# 4  [an, amazing, work, environment, where, everyone, is, very, smart, and, friendly, ., i, have, le...
# 5  [a, productive, and, innovative, culture, and, environment, ., fostered, creativity, and, did, n...
#
#                                                                                                no_punc  \
# 0  [contracted, to, design, custom, pitot, test, adapters, involved, multiple, design, phases, and,...
# 1  [lots, of, support, and, collaboration, across, many, engaging, projects, you, are, given, an, o...
# 2  [work, is, responsibility, culture, is, great, the, hardest, part, of, job, is, that, it, is, ve...
# 4  [an, amazing, work, environment, where, everyone, is, very, smart, and, friendly, i, have, learn...
# 5  [a, productive, and, innovative, culture, and, environment, fostered, creativity, and, did, not,...
#
#                                                                                      stopwords_removed
# 0  [contracted, design, custom, pitot, test, adapters, involved, multiple, design, phases, prototyp...
# 1  [lots, support, collaboration, across, many, engaging, projects, given, opportunity, grow, ideas...
# 2  [work, responsibility, culture, great, hardest, part, job, hectic, management, good, google, ads...
# 4  [amazing, work, environment, everyone, smart, friendly, learned, lot, great, coworkers, amazing,...
# 5  [productive, innovative, culture, environment, fostered, creativity, limit, potential, positive,...

# %%
rws['pos_tags'] = rws['stopwords_removed'].apply(nltk.tag.pos_tag)
rws.head()
# Out:
#    rating  \
# 0       4
# 1       5
# 2       5
# 4       5
# 5       5
#
#                                                                                     rating_description  \
# 0  Contracted to design custom pitot test adapters. Involved multiple design phases and prototypes....
# 1  Lots of support and collaboration across many engaging projects. You are given an opportunity to...
# 2  Work is responsibility. Culture is great. The Hardest part of job is that it is very hectic. Man...
# 4  An amazing work environment where everyone is very smart and friendly. I have learned a lot from...
# 5  A productive and innovative culture and environment. Fostered creativity and did not limit your ...
#
#                                                                                            no_contract  \
# 0  [Contracted, to, design, custom, pitot, test, adapters., Involved, multiple, design, phases, and...
# 1  [Lots, of, support, and, collaboration, across, many, engaging, projects., You, are, given, an, ...
# 2  [Work, is, responsibility., Culture, is, great., The, Hardest, part, of, job, is, that, it, is, ...
# 4  [An, amazing, work, environment, where, everyone, is, very, smart, and, friendly., I, have, lear...
# 5  [A, productive, and, innovative, culture, and, environment., Fostered, creativity, and, did, not...
#
#                                                                                 rating_description_str  \
# 0  Contracted to design custom pitot test adapters. Involved multiple design phases and prototypes....
# 1  Lots of support and collaboration across many engaging projects. You are given an opportunity to...
# 2  Work is responsibility. Culture is great. The Hardest part of job is that it is very hectic. Man...
# 4  An amazing work environment where everyone is very smart and friendly. I have learned a lot from...
# 5  A productive and innovative culture and environment. Fostered creativity and did not limit your ...
#
#   langs  \
# 0    en
# 1    en
# 2    en
# 4    en
# 5    en
#
#                                                                                              tokenized  \
# 0  [Contracted, to, design, custom, pitot, test, adapters, ., Involved, multiple, design, phases, a...
# 1  [Lots, of, support, and, collaboration, across, many, engaging, projects, ., You, are, given, an...
# 2  [Work, is, responsibility, ., Culture, is, great, ., The, Hardest, part, of, job, is, that, it, ...
# 4  [An, amazing, work, environment, where, everyone, is, very, smart, and, friendly, ., I, have, le...
# 5  [A, productive, and, innovative, culture, and, environment, ., Fostered, creativity, and, did, n...
#
#                                                                                                  lower  \
# 0  [contracted, to, design, custom, pitot, test, adapters, ., involved, multiple, design, phases, a...
# 1  [lots, of, support, and, collaboration, across, many, engaging, projects, ., you, are, given, an...
# 2  [work, is, responsibility, ., culture, is, great, ., the, hardest, part, of, job, is, that, it, ...
# 4  [an, amazing, work, environment, where, everyone, is, very, smart, and, friendly, ., i, have, le...
# 5  [a, productive, and, innovative, culture, and, environment, ., fostered, creativity, and, did, n...
#
#                                                                                                no_punc  \
# 0  [contracted, to, design, custom, pitot, test, adapters, involved, multiple, design, phases, and,...
# 1  [lots, of, support, and, collaboration, across, many, engaging, projects, you, are, given, an, o...
# 2  [work, is, responsibility, culture, is, great, the, hardest, part, of, job, is, that, it, is, ve...
# 4  [an, amazing, work, environment, where, everyone, is, very, smart, and, friendly, i, have, learn...
# 5  [a, productive, and, innovative, culture, and, environment, fostered, creativity, and, did, not,...
#
#                                                                                      stopwords_removed  \
# 0  [contracted, design, custom, pitot, test, adapters, involved, multiple, design, phases, prototyp...
# 1  [lots, support, collaboration, across, many, engaging, projects, given, opportunity, grow, ideas...
# 2  [work, responsibility, culture, great, hardest, part, job, hectic, management, good, google, ads...
# 4  [amazing, work, environment, everyone, smart, friendly, learned, lot, great, coworkers, amazing,...
# 5  [productive, innovative, culture, environment, fostered, creativity, limit, potential, positive,...
#
#                                                                                               pos_tags
# 0  [(contracted, VBN), (design, NN), (custom, NN), (pitot, JJ), (test, NN), (adapters, NNS), (invol...
# 1  [(lots, NNS), (support, NN), (collaboration, NN), (across, IN), (many, JJ), (engaging, VBG), (pr...
# 2  [(work, NN), (responsibility, NN), (culture, NN), (great, JJ), (hardest, JJS), (part, NN), (job,...
# 4  [(amazing, VBG), (work, NN), (environment, NN), (everyone, NN), (smart, JJ), (friendly, RB), (le...
# 5  [(productive, JJ), (innovative, JJ), (culture, NN), (environment, NN), (fostered, VBD), (creativ...

# %%
def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
rws['wordnet_pos'] = rws['pos_tags'].apply(lambda x: [(word, get_wordnet_pos(pos_tag)) for (word, pos_tag) in x])
rws.head()
# Out:
#    rating  \
# 0       4
# 1       5
# 2       5
# 4       5
# 5       5
#
#                                                                                     rating_description  \
# 0  Contracted to design custom pitot test adapters. Involved multiple design phases and prototypes....
# 1  Lots of support and collaboration across many engaging projects. You are given an opportunity to...
# 2  Work is responsibility. Culture is great. The Hardest part of job is that it is very hectic. Man...
# 4  An amazing work environment where everyone is very smart and friendly. I have learned a lot from...
# 5  A productive and innovative culture and environment. Fostered creativity and did not limit your ...
#
#                                                                                            no_contract  \
# 0  [Contracted, to, design, custom, pitot, test, adapters., Involved, multiple, design, phases, and...
# 1  [Lots, of, support, and, collaboration, across, many, engaging, projects., You, are, given, an, ...
# 2  [Work, is, responsibility., Culture, is, great., The, Hardest, part, of, job, is, that, it, is, ...
# 4  [An, amazing, work, environment, where, everyone, is, very, smart, and, friendly., I, have, lear...
# 5  [A, productive, and, innovative, culture, and, environment., Fostered, creativity, and, did, not...
#
#                                                                                 rating_description_str  \
# 0  Contracted to design custom pitot test adapters. Involved multiple design phases and prototypes....
# 1  Lots of support and collaboration across many engaging projects. You are given an opportunity to...
# 2  Work is responsibility. Culture is great. The Hardest part of job is that it is very hectic. Man...
# 4  An amazing work environment where everyone is very smart and friendly. I have learned a lot from...
# 5  A productive and innovative culture and environment. Fostered creativity and did not limit your ...
#
#   langs  \
# 0    en
# 1    en
# 2    en
# 4    en
# 5    en
#
#                                                                                              tokenized  \
# 0  [Contracted, to, design, custom, pitot, test, adapters, ., Involved, multiple, design, phases, a...
# 1  [Lots, of, support, and, collaboration, across, many, engaging, projects, ., You, are, given, an...
# 2  [Work, is, responsibility, ., Culture, is, great, ., The, Hardest, part, of, job, is, that, it, ...
# 4  [An, amazing, work, environment, where, everyone, is, very, smart, and, friendly, ., I, have, le...
# 5  [A, productive, and, innovative, culture, and, environment, ., Fostered, creativity, and, did, n...
#
#                                                                                                  lower  \
# 0  [contracted, to, design, custom, pitot, test, adapters, ., involved, multiple, design, phases, a...
# 1  [lots, of, support, and, collaboration, across, many, engaging, projects, ., you, are, given, an...
# 2  [work, is, responsibility, ., culture, is, great, ., the, hardest, part, of, job, is, that, it, ...
# 4  [an, amazing, work, environment, where, everyone, is, very, smart, and, friendly, ., i, have, le...
# 5  [a, productive, and, innovative, culture, and, environment, ., fostered, creativity, and, did, n...
#
#                                                                                                no_punc  \
# 0  [contracted, to, design, custom, pitot, test, adapters, involved, multiple, design, phases, and,...
# 1  [lots, of, support, and, collaboration, across, many, engaging, projects, you, are, given, an, o...
# 2  [work, is, responsibility, culture, is, great, the, hardest, part, of, job, is, that, it, is, ve...
# 4  [an, amazing, work, environment, where, everyone, is, very, smart, and, friendly, i, have, learn...
# 5  [a, productive, and, innovative, culture, and, environment, fostered, creativity, and, did, not,...
#
#                                                                                      stopwords_removed  \
# 0  [contracted, design, custom, pitot, test, adapters, involved, multiple, design, phases, prototyp...
# 1  [lots, support, collaboration, across, many, engaging, projects, given, opportunity, grow, ideas...
# 2  [work, responsibility, culture, great, hardest, part, job, hectic, management, good, google, ads...
# 4  [amazing, work, environment, everyone, smart, friendly, learned, lot, great, coworkers, amazing,...
# 5  [productive, innovative, culture, environment, fostered, creativity, limit, potential, positive,...
#
#                                                                                               pos_tags  \
# 0  [(contracted, VBN), (design, NN), (custom, NN), (pitot, JJ), (test, NN), (adapters, NNS), (invol...
# 1  [(lots, NNS), (support, NN), (collaboration, NN), (across, IN), (many, JJ), (engaging, VBG), (pr...
# 2  [(work, NN), (responsibility, NN), (culture, NN), (great, JJ), (hardest, JJS), (part, NN), (job,...
# 4  [(amazing, VBG), (work, NN), (environment, NN), (everyone, NN), (smart, JJ), (friendly, RB), (le...
# 5  [(productive, JJ), (innovative, JJ), (culture, NN), (environment, NN), (fostered, VBD), (creativ...
#
#                                                                                            wordnet_pos
# 0  [(contracted, v), (design, n), (custom, n), (pitot, a), (test, n), (adapters, n), (involved, v),...
# 1  [(lots, n), (support, n), (collaboration, n), (across, n), (many, a), (engaging, v), (projects, ...
# 2  [(work, n), (responsibility, n), (culture, n), (great, a), (hardest, a), (part, n), (job, n), (h...
# 4  [(amazing, v), (work, n), (environment, n), (everyone, n), (smart, a), (friendly, r), (learned, ...
# 5  [(productive, a), (innovative, a), (culture, n), (environment, n), (fostered, v), (creativity, n...

# %%
wnl = WordNetLemmatizer()
rws['lemmatized'] = rws['wordnet_pos'].apply(lambda x: [wnl.lemmatize(word, tag) for word, tag in x])
rws.head()
# Out:
#    rating  \
# 0       4
# 1       5
# 2       5
# 4       5
# 5       5
#
#                                                                                     rating_description  \
# 0  Contracted to design custom pitot test adapters. Involved multiple design phases and prototypes....
# 1  Lots of support and collaboration across many engaging projects. You are given an opportunity to...
# 2  Work is responsibility. Culture is great. The Hardest part of job is that it is very hectic. Man...
# 4  An amazing work environment where everyone is very smart and friendly. I have learned a lot from...
# 5  A productive and innovative culture and environment. Fostered creativity and did not limit your ...
#
#                                                                                            no_contract  \
# 0  [Contracted, to, design, custom, pitot, test, adapters., Involved, multiple, design, phases, and...
# 1  [Lots, of, support, and, collaboration, across, many, engaging, projects., You, are, given, an, ...
# 2  [Work, is, responsibility., Culture, is, great., The, Hardest, part, of, job, is, that, it, is, ...
# 4  [An, amazing, work, environment, where, everyone, is, very, smart, and, friendly., I, have, lear...
# 5  [A, productive, and, innovative, culture, and, environment., Fostered, creativity, and, did, not...
#
#                                                                                 rating_description_str  \
# 0  Contracted to design custom pitot test adapters. Involved multiple design phases and prototypes....
# 1  Lots of support and collaboration across many engaging projects. You are given an opportunity to...
# 2  Work is responsibility. Culture is great. The Hardest part of job is that it is very hectic. Man...
# 4  An amazing work environment where everyone is very smart and friendly. I have learned a lot from...
# 5  A productive and innovative culture and environment. Fostered creativity and did not limit your ...
#
#   langs  \
# 0    en
# 1    en
# 2    en
# 4    en
# 5    en
#
#                                                                                              tokenized  \
# 0  [Contracted, to, design, custom, pitot, test, adapters, ., Involved, multiple, design, phases, a...
# 1  [Lots, of, support, and, collaboration, across, many, engaging, projects, ., You, are, given, an...
# 2  [Work, is, responsibility, ., Culture, is, great, ., The, Hardest, part, of, job, is, that, it, ...
# 4  [An, amazing, work, environment, where, everyone, is, very, smart, and, friendly, ., I, have, le...
# 5  [A, productive, and, innovative, culture, and, environment, ., Fostered, creativity, and, did, n...
#
#                                                                                                  lower  \
# 0  [contracted, to, design, custom, pitot, test, adapters, ., involved, multiple, design, phases, a...
# 1  [lots, of, support, and, collaboration, across, many, engaging, projects, ., you, are, given, an...
# 2  [work, is, responsibility, ., culture, is, great, ., the, hardest, part, of, job, is, that, it, ...
# 4  [an, amazing, work, environment, where, everyone, is, very, smart, and, friendly, ., i, have, le...
# 5  [a, productive, and, innovative, culture, and, environment, ., fostered, creativity, and, did, n...
#
#                                                                                                no_punc  \
# 0  [contracted, to, design, custom, pitot, test, adapters, involved, multiple, design, phases, and,...
# 1  [lots, of, support, and, collaboration, across, many, engaging, projects, you, are, given, an, o...
# 2  [work, is, responsibility, culture, is, great, the, hardest, part, of, job, is, that, it, is, ve...
# 4  [an, amazing, work, environment, where, everyone, is, very, smart, and, friendly, i, have, learn...
# 5  [a, productive, and, innovative, culture, and, environment, fostered, creativity, and, did, not,...
#
#                                                                                      stopwords_removed  \
# 0  [contracted, design, custom, pitot, test, adapters, involved, multiple, design, phases, prototyp...
# 1  [lots, support, collaboration, across, many, engaging, projects, given, opportunity, grow, ideas...
# 2  [work, responsibility, culture, great, hardest, part, job, hectic, management, good, google, ads...
# 4  [amazing, work, environment, everyone, smart, friendly, learned, lot, great, coworkers, amazing,...
# 5  [productive, innovative, culture, environment, fostered, creativity, limit, potential, positive,...
#
#                                                                                               pos_tags  \
# 0  [(contracted, VBN), (design, NN), (custom, NN), (pitot, JJ), (test, NN), (adapters, NNS), (invol...
# 1  [(lots, NNS), (support, NN), (collaboration, NN), (across, IN), (many, JJ), (engaging, VBG), (pr...
# 2  [(work, NN), (responsibility, NN), (culture, NN), (great, JJ), (hardest, JJS), (part, NN), (job,...
# 4  [(amazing, VBG), (work, NN), (environment, NN), (everyone, NN), (smart, JJ), (friendly, RB), (le...
# 5  [(productive, JJ), (innovative, JJ), (culture, NN), (environment, NN), (fostered, VBD), (creativ...
#
#                                                                                            wordnet_pos  \
# 0  [(contracted, v), (design, n), (custom, n), (pitot, a), (test, n), (adapters, n), (involved, v),...
# 1  [(lots, n), (support, n), (collaboration, n), (across, n), (many, a), (engaging, v), (projects, ...
# 2  [(work, n), (responsibility, n), (culture, n), (great, a), (hardest, a), (part, n), (job, n), (h...
# 4  [(amazing, v), (work, n), (environment, n), (everyone, n), (smart, a), (friendly, r), (learned, ...
# 5  [(productive, a), (innovative, a), (culture, n), (environment, n), (fostered, v), (creativity, n...
#
#                                                                                             lemmatized
# 0  [contract, design, custom, pitot, test, adapter, involve, multiple, design, phase, prototypes, f...
# 1  [lot, support, collaboration, across, many, engage, project, give, opportunity, grow, idea, resp...
# 2  [work, responsibility, culture, great, hard, part, job, hectic, management, good, google, ad, le...
# 4  [amaze, work, environment, everyone, smart, friendly, learn, lot, great, coworkers, amaze, manag...
# 5  [productive, innovative, culture, environment, foster, creativity, limit, potential, positive, t...

# %%
with open('indeed_scrape_clean.pkl', 'wb') as pickle_file:
    pickle.dump(rws, pickle_file)
